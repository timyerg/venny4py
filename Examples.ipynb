# %%
# !pip install venny4py
# Out:
# Collecting venny4py
#   Using cached venny4py-1.0.3-py3-none-any.whl.metadata (1.8 kB)
# Using cached venny4py-1.0.3-py3-none-any.whl (4.5 kB)
# Installing collected packages: venny4py
# Successfully installed venny4py-1.0.3

# %%
# !mkdir Example_output
# Out:
# mkdir: cannot create directory ‘Example_output’: File exists

# %% [markdown]
# # Venn 4 sets

# %%
from venny4py.venny4py import *
# %matplotlib inline

#dict of sets
sets = {
    'Set1': set(list("Harry Potter")),
    'Set2': set(list("Hermione Granger")),
    'Set3': set(list("Ron Weasley")),
    'Set4': set(list("Severus Snape"))
}

venny4py(sets=sets, out='Example_output')

# %%
from venny4py.venny4py import *
# %matplotlib inline

#dict of sets
sets = {
    'Set1': set(list("Harry Potter")),
    'Set2': set(list("Hermione Granger")),
    'Set3': set(list("Ron Weasley")),
    'Set4': set(list("Severus Snape"))
}

venny4py(sets=sets, out='Example_output', colors='crgb', legend_cols=4,
        edge_color='purple', column_spacing=2, line_width=.5)

# %% [markdown]
# # Venn 3 sets

# %%
from venny4py.venny4py import *
# %matplotlib inline

#dict of sets
sets = {
    'Set1': set(list("Harry Potter")),
    'Set2': set(list("Hermione Granger")),
    'Set3': set(list("Ron Weasley")),
    #'Set4': set(list("Severus Snape"))
}

venny4py(sets=sets, out='Example_output')

# %% [markdown]
# # Venn 2 sets

# %%
from venny4py.venny4py import *
# %matplotlib inline

#dict of sets
sets = {
    'Set1': set(list("Harry Potter")),
    'Set2': set(list("Hermione Granger")),
    #'Set3': set(list("Ron Weasley")),
    #'Set4': set(list("Severus Snape"))
}

venny4py(sets=sets, out='Example_output')

# %% [markdown]
# # Specify dpi and figsize

# %%
from venny4py.venny4py import *
# %matplotlib inline

#dict of sets
sets = {
    'Set1': set(list("Harry Potter")),
    'Set2': set(list("Hermione Granger")),
    'Set3': set(list("Ron Weasley")),
    'Set4': set(list("Severus Snape"))
}

venny4py(sets=sets, size=6, dpi=600, out='Example_output', ext='svg')

# %% [markdown]
# # As ax, or matplotlib subplot

# %%
from venny4py.venny4py import *
import matplotlib.pyplot as plt
# %matplotlib inline

#dict of sets
sets = {
    'Set1': set(list("Harry Potter")),
    'Set2': set(list("Hermione Granger")),
    'Set3': set(list("Ron Weasley")),
    'Set4': set(list("Severus Snape"))
}

fig, axes = plt.subplots(1, 2, figsize=(6.5, 3), dpi=600)
ax = axes[1]
venny4py(sets=sets, size=3, asax=ax, out='Example_output') #indicate approx. size of subplot, not the figure!
